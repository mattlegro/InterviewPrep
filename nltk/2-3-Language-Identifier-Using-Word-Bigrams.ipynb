# %% [markdown]
# # Language Identifier Using Word Bigrams

# %% [markdown]
# Based on [Language Identifier by asif31iqbal](https://github.com/asif31iqbal/language-identifier)

# %% [markdown]
# ## 0. Importing libraries and creating helper tokenize method

# %%
import pickle
import string
import os
from nltk import ngrams, FreqDist, word_tokenize
from numpy import arange
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def ultimate_tokenize(sentence):
    # Remove punctuation and digits
    sentence = sentence.translate(str.maketrans('', '', string.punctuation + string.digits))
    return word_tokenize(sentence.lower())

# %% [markdown]
# ## 1. Understanding the process

# %%
simple_example_text = 'Oh, then, I see Queen Mab hath been with you.'

simple_example_tokens_words = ultimate_tokenize(simple_example_text)
simple_example_tokens_words
# Out:
# ['oh', 'then', 'i', 'see', 'queen', 'mab', 'hath', 'been', 'with', 'you']

# %%
simple_example_tokens_chars = list(simple_example_tokens_words[0])
simple_example_tokens_chars
# Out:
# ['o', 'h']

# %%
simple_example_tokens_words_unigrams = list(ngrams(simple_example_tokens_words, 1))
simple_example_tokens_words_unigrams
# Out:
# [('oh',),
#  ('then',),
#  ('i',),
#  ('see',),
#  ('queen',),
#  ('mab',),
#  ('hath',),
#  ('been',),
#  ('with',),
#  ('you',)]

# %%
simple_example_tokens_words_bigrams = list(ngrams(simple_example_tokens_words, 2, pad_left=True, pad_right=True, left_pad_symbol='_', right_pad_symbol='_'))
simple_example_tokens_words_bigrams
# Out:
# [('_', 'oh'),
#  ('oh', 'then'),
#  ('then', 'i'),
#  ('i', 'see'),
#  ('see', 'queen'),
#  ('queen', 'mab'),
#  ('mab', 'hath'),
#  ('hath', 'been'),
#  ('been', 'with'),
#  ('with', 'you'),
#  ('you', '_')]

# %%
fdist = FreqDist(simple_example_tokens_words_unigrams)
fdist
# Out:
# FreqDist({('oh',): 1, ('then',): 1, ('i',): 1, ('see',): 1, ('queen',): 1, ('mab',): 1, ('hath',): 1, ('been',): 1, ('with',): 1, ('you',): 1})

# %%
unigram_dict = dict()
for k, v in fdist.items():
        unigram_dict[' '.join(k)] = v
unigram_dict
# Out:
# {'oh': 1,
#  'then': 1,
#  'i': 1,
#  'see': 1,
#  'queen': 1,
#  'mab': 1,
#  'hath': 1,
#  'been': 1,
#  'with': 1,
#  'you': 1}

# %%
file = 'C:/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/ngram_langid_files/LangId.train.English.txt'
with open(file, encoding='utf8') as f:
        content = f.read().lower()
content.replace('\n', '')[:100]
# Out:
# "approval of the minutes of the previous sitting the minutes of yesterday 's sitting have been distri"

# %%
with open('C:/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/ngram_langid_files/English.unigram.pickle', 'rb') as handle:
    unigram_english_dict = pickle.load(handle)
unigram_english_dict
# Out:
# {'approval': 3,
#  'of': 2769,
#  'the': 5699,
#  'minutes': 11,
#  'previous': 13,
#  'sitting': 11,
#  'yesterday': 15,
#  's': 244,
#  'have': 491,
#  'been': 193,
#  'distributed': 4,
#  'are': 571,
#  'there': 229,
#  'any': 98,
#  'comments': 9,
#  'mr': 371,
#  'president': 270,
#  'on': 865,
#  'monday': 11,
#  'i': 721,
#  'made': 61,
#  'a': 1343,
#  'point': 70,
#  'order': 76,
#  'about': 93,
#  'nicole': 1,
#  'fontaine': 4,
#  'reported': 2,
#  'in': 1668,
#  'british': 16,
#  'press': 13,
#  'regarding': 23,
#  'her': 51,
#  'recent': 12,
#  'visit': 6,
#  'with': 449,
#  'majesty': 1,
#  'queen': 3,
#  'elizabeth': 1,
#  'ii': 1,
#  'labour': 14,
#  'member': 111,
#  'this': 887,
#  'house': 49,
#  'miller': 2,
#  'repeated': 6,
#  'what': 132,
#  'were': 82,
#  'purported': 1,
#  'to': 2490,
#  'be': 620,
#  'remarks': 1,
#  'not': 525,
#  'once': 27,
#  'but': 240,
#  'three': 21,
#  'times': 11,
#  'tuesday': 8,
#  'and': 2040,
#  'wednesday': 2,
#  'he': 72,
#  'sought': 5,
#  'drag': 1,
#  'into': 78,
#  'political': 51,
#  'controversy': 2,
#  'use': 45,
#  'name': 16,
#  'score': 2,
#  'cheap': 7,
#  'points': 23,
#  'it': 694,
#  'may': 59,
#  'that': 1205,
#  'was': 163,
#  'unfamiliar': 1,
#  'rules': 25,
#  'protocol': 3,
#  'which': 496,
#  'obtain': 6,
#  'such': 102,
#  'matters': 26,
#  'has': 339,
#  'no': 116,
#  'excuse': 3,
#  'knows': 8,
#  'perfectly': 8,
#  'well': 79,
#  'ours': 3,
#  'is': 1303,
#  'non': 38,
#  'head': 10,
#  'state': 39,
#  'for': 821,
#  'nearly': 2,
#  'fifty': 3,
#  'years': 69,
#  'she': 32,
#  'scrupulously': 1,
#  'avoided': 3,
#  'engaging': 1,
#  'controversial': 2,
#  'issues': 26,
#  'can': 220,
#  'come': 30,
#  'set': 31,
#  'record': 6,
#  'straight': 2,
#  'his': 57,
#  'behaviour': 15,
#  'disgrace': 1,
#  'scandal': 3,
#  'am': 80,
#  'proud': 2,
#  'today': 64,
#  'ashamed': 1,
#  'share': 14,
#  'my': 109,
#  'nationality': 3,
#  'man': 6,
#  'shame': 2,
#  'respect': 39,
#  'decency': 1,
#  'or': 177,
#  'honour': 3,
#  'at': 274,
#  'all': 222,
#  'wish': 40,
#  'speak': 9,
#  'capacity': 12,
#  'as': 552,
#  'chairman': 9,
#  'delegation': 8,
#  'relations': 15,
#  'countries': 66,
#  'central': 13,
#  'america': 14,
#  'mexico': 3,
#  'you': 117,
#  'will': 277,
#  'aware': 24,
#  'elections': 4,
#  'held': 10,
#  'last': 56,
#  'sunday': 1,
#  'chair': 1,
#  'met': 5,
#  'discussed': 6,
#  'report': 286,
#  'drawn': 6,
#  'up': 134,
#  'by': 453,
#  'our': 208,
#  'fellow': 18,
#  'members': 60,
#  'who': 153,
#  'had': 53,
#  'act': 13,
#  'observers': 4,
#  'these': 162,
#  'behalf': 87,
#  'parliament': 189,
#  'would': 273,
#  'ask': 41,
#  'see': 45,
#  'if': 155,
#  'could': 64,
#  'forward': 22,
#  'resolution': 119,
#  'complete': 10,
#  'text': 34,
#  'receive': 16,
#  'mexican': 1,
#  'authorities': 40,
#  'ladies': 33,
#  'gentlemen': 33,
#  'want': 48,
#  'draw': 12,
#  'your': 26,
#  'attention': 31,
#  'something': 25,
#  'really': 30,
#  'annoying': 1,
#  'connection': 10,
#  'x': 49,
#  'texts': 7,
#  'adopted': 34,
#  'also': 221,
#  'form': 19,
#  'part': 64,
#  'pointed': 11,
#  'out': 105,
#  'during': 60,
#  'vote': 91,
#  'directive': 77,
#  'combat': 6,
#  'money': 16,
#  'laundering': 1,
#  'english': 9,
#  'translation': 3,
#  'article': 21,
#  'needs': 37,
#  'corrected': 2,
#  'bring': 17,
#  'line': 17,
#  'amendment': 38,
#  'because': 118,
#  'wrong': 11,
#  'middle': 3,
#  'second': 25,
#  'paragraph': 8,
#  'version': 6,
#  'only': 113,
#  'reference': 9,
#  'representation': 3,
#  'legal': 32,
#  'proceedings': 8,
#  'consultants': 1,
#  'german': 3,
#  'key': 14,
#  'since': 40,
#  'council': 85,
#  'working': 49,
#  'group': 131,
#  'basis': 28,
#  'quite': 28,
#  'crucial': 10,
#  'correct': 13,
#  'already': 41,
#  'complained': 2,
#  'committee': 134,
#  'vis': 4,
#  'language': 4,
#  'services': 46,
#  'time': 123,
#  'decided': 10,
#  'table': 2,
#  'an': 266,
#  'original': 5,
#  'drafted': 4,
#  'rapporteur': 49,
#  'situation': 67,
#  'remedied': 2,
#  'third': 12,
#  'complaining': 2,
#  'do': 149,
#  'think': 41,
#  'should': 222,
#  'work': 118,
#  'more': 176,
#  'carefully': 8,
#  'questions': 12,
#  'intolerable': 4,
#  'despite': 14,
#  'criticism': 9,
#  'got': 11,
#  'again': 36,
#  'get': 18,
#  'bottom': 2,
#  'matter': 57,
#  'sort': 11,
#  'most': 63,
#  'important': 91,
#  'aspect': 11,
#  'please': 7,
#  'we': 864,
#  'received': 15,
#  'communication': 18,
#  'yellow': 1,
#  'paper': 6,
#  'from': 226,
#  'vice': 18,
#  'some': 85,
#  'nuts': 3,
#  'attached': 3,
#  'note': 17,
#  'supporting': 7,
#  'export': 3,
#  'products': 1,
#  'vanuatu': 1,
#  'developing': 8,
#  'country': 36,
#  'pacific': 3,
#  'very': 129,
#  'good': 68,
#  'idea': 12,
#  'right': 80,
#  'happy': 8,
#  'support': 98,
#  'rather': 31,
#  'puzzles': 1,
#  'me': 58,
#  'explicitly': 1,
#  'stated': 9,
#  'illegal': 11,
#  'import': 2,
#  'european': 389,
#  'union': 120,
#  'so': 163,
#  'must': 228,
#  'explain': 6,
#  'how': 49,
#  'came': 3,
#  'illegally': 1,
#  'imported': 2,
#  'delivered': 1,
#  'them': 83,
#  'us': 100,
#  'itself': 20,
#  'contradiction': 3,
#  'clarify': 4,
#  'laughter': 1,
#  'applause': 3,
#  'approved': 11,
#  'welcome': 12,
#  'petitions': 71,
#  'ombudsman': 110,
#  'next': 29,
#  'item': 17,
#  'joint': 25,
#  'debate': 58,
#  'following': 20,
#  'reports': 31,
#  'tabled': 14,
#  'mrs': 117,
#  'lambert': 14,
#  'deliberations': 3,
#  'parliamentary': 13,
#  'year': 67,
#  'thors': 12,
#  'annual': 12,
#  'activities': 19,
#  'glad': 3,
#  'opportunity': 19,
#  'address': 17,
#  'concerning': 15,
#  'results': 15,
#  'covers': 2,
#  'first': 60,
#  'mandate': 10,
#  'office': 17,
#  'new': 69,
#  'complaints': 32,
#  'compared': 4,
#  'increase': 33,
#  'number': 67,
#  'inquiries': 6,
#  'opened': 3,
#  'rose': 2,
#  'over': 52,
#  'becoming': 15,
#  'better': 25,
#  'known': 19,
#  'attracting': 1,
#  'higher': 3,
#  'proportion': 7,
#  'serious': 36,
#  'require': 8,
#  'full': 25,
#  'investigation': 9,
#  'interested': 9,
#  'know': 53,
#  'same': 46,
#  'trend': 6,
#  'continued': 6,
#  'present': 38,
#  'six': 9,
#  'months': 14,
#  'period': 24,
#  'resource': 2,
#  'intensive': 1,
#  'therefore': 98,
#  'great': 47,
#  'challenge': 3,
#  'deal': 21,
#  'whilst': 3,
#  'maintaining': 4,
#  'quality': 16,
#  'meeting': 7,
#  'target': 2,
#  'closing': 2,
#  'within': 60,
#  'one': 131,
#  'hope': 36,
#  'seeking': 5,
#  'resources': 16,
#  'needed': 10,
#  'carry': 7,
#  'effectively': 13,
#  'high': 36,
#  'lay': 4,
#  'outside': 14,
#  'even': 64,
#  'increased': 7,
#  'slightly': 2,
#  'probably': 11,
#  'growing': 13,
#  'e': 6,
#  'mail': 6,
#  'gladly': 1,
#  'accept': 16,
#  'many': 74,
#  'contain': 6,
#  'presented': 15,
#  'allegations': 2,
#  'maladministration': 8,
#  'however': 83,
#  'directed': 6,
#  'against': 82,
#  'states': 144,
#  'campaign': 8,
#  'election': 3,
#  'critical': 12,
#  'voices': 2,
#  'suggested': 5,
#  'broadened': 1,
#  'include': 16,
#  'cases': 32,
#  'where': 58,
#  'question': 30,
#  'law': 40,
#  'involved': 21,
#  'sure': 18,
#  'whether': 28,
#  'they': 190,
#  'understood': 2,
#  'mean': 17,
#  'carrying': 6,
#  'tasks': 3,
#  'currently': 20,
#  'belonging': 1,
#  'commission': 274,
#  'guardian': 1,
#  'treaty': 24,
#  'democratic': 9,
#  'forum': 2,
#  'citizens': 92,
#  'study': 7,
#  'especially': 29,
#  'involve': 5,
#  'rights': 81,
#  'under': 47,
#  'managed': 8,
#  'advise': 1,
#  'complainant': 3,
#  'transfer': 2,
#  'complaint': 8,
#  'competent': 3,
#  'body': 16,
#  'half': 5,
#  'transferred': 2,
#  'dealt': 7,
#  'advised': 2,
#  'further': 38,
#  'complainants': 1,
#  'their': 190,
#  'petition': 10,
#  'national': 69,
#  'regional': 21,
#  'local': 13,
#  'concerned': 40,
#  'every': 32,
#  'judicial': 4,
#  'assist': 2,
#  'conflicts': 12,
#  'administration': 35,
#  'believer': 1,
#  'subsidiarity': 7,
#  'remain': 14,
#  'convinced': 9,
#  'effective': 28,
#  'way': 86,
#  'achieve': 21,
#  'result': 27,
#  'through': 29,
#  'development': 37,
#  'network': 4,
#  'cooperation': 45,
#  'ombudsmen': 11,
#  'similar': 13,
#  'bodies': 27,
#  'committees': 11,
#  'organised': 4,
#  'jointly': 7,
#  'french': 16,
#  'stasi': 1,
#  'seminar': 3,
#  'paris': 6,
#  'september': 8,
#  'perry': 2,
#  'represented': 5,
#  'planned': 4,
#  'take': 102,
#  'place': 31,
#  'brussels': 8,
#  'belgian': 6,
#  'presidency': 15,
#  'belgium': 3,
#  'federal': 7,
#  'invited': 3,
#  'florence': 1,
#  'gemelli': 3,
#  'attended': 3,
#  'shown': 12,
#  'positive': 17,
#  'attitude': 13,
#  'towards': 25,
#  'strongly': 10,
#  'believe': 61,
#  'equal': 6,
#  'terms': 49,
#  'best': 15,
#  'beginning': 8,
#  'doubts': 9,
#  'expressed': 12,
#  'sufficient': 11,
#  'powers': 8,
#  'anything': 10,
#  'citizen': 12,
#  'unjustified': 1,
#  'community': 65,
#  'institutions': 47,
#  'responded': 2,
#  'properly': 8,
#  'themselves': 16,
#  'settled': 1,
#  'satisfaction': 5,
#  'example': 32,
#  'replied': 3,
#  'unanswered': 1,
#  'letters': 1,
#  'payments': 2,
#  'due': 17,
#  'reversed': 3,
#  'unfavourable': 1,
#  'decisions': 22,
#  'indicates': 4,
#  'spirit': 6,
#  'responsiveness': 1,
#  'flexibility': 6,
#  'superior': 1,
#  'those': 93,
#  'administrations': 9,
#  'experience': 14,
#  'sixty': 1,
#  'two': 49,
#  'settlements': 1,
#  'occurred': 5,
#  'reducing': 8,
#  'scope': 5,
#  'friendly': 11,
#  'solutions': 13,
#  'proposed': 19,
#  'did': 25,
#  'solution': 20,
#  'case': 54,
#  'agreed': 12,
#  'paid': 8,
#  'amount': 6,
#  'him': 20,
#  'coordinator': 1,
#  'monitoring': 35,
#  'palestinian': 1,
#  'institution': 21,
#  'ultimate': 2,
#  'weapon': 3,
#  'draft': 19,
#  'recommendation': 14,
#  'followed': 5,
#  'necessary': 48,
#  'special': 18,
#  'five': 13,
#  'ago': 19,
#  'people': 126,
#  'said': 38,
#  'pay': 11,
#  'much': 59,
#  'heed': 1,
#  'might': 18,
#  'then': 36,
#  'things': 18,
#  'clearly': 28,
#  'changed': 6,
#  'amsterdam': 3,
#  'fall': 3,
#  'santer': 1,
#  'ten': 10,
#  'recommendations': 3,
#  'seven': 4,
#  'accepted': 9,
#  'remains': 6,
#  'ongoing': 2,
#  'europol': 3,
#  'comply': 5,
#  'approve': 4,
#  'public': 68,
#  'access': 28,
#  'documents': 20,
#  'reached': 4,
#  'level': 44,
#  'expect': 6,
#  'consists': 4,
#  'persons': 3,
#  'fairly': 3,
#  'complex': 6,
#  'environment': 19,
#  'achieving': 6,
#  'above': 10,
#  'like': 144,
#  'thank': 35,
#  'another': 30,
#  'constructive': 4,
#  'its': 146,
#  'responsible': 22,
#  'loyola': 1,
#  'de': 23,
#  'palacio': 13,
#  'continuing': 4,
#  'predecessor': 2,
#  'commitment': 4,
#  'honest': 2,
#  'express': 21,
#  'warm': 4,
#  'appreciation': 3,
#  'helpful': 2,
#  'cooperative': 1,
#  'comprehensive': 6,
#  'presenting': 3,
#  'morning': 11,
#  'dual': 3,
#  'reflects': 6,
#  'mediator': 1,
#  'transnationally': 1,
#  'abducted': 2,
#  'children': 40,
#  'banotti': 1,
#  'personal': 6,
#  'soederman': 19,
#  'secretariat': 3,
#  'least': 30,
#  'statistical': 3,
#  'break': 9,
#  'down': 26,
#  'provided': 17,
#  'confess': 1,
#  'own': 41,
#  'urge': 17,
#  'familiar': 3,
#  'read': 5,
#  'providing': 3,
#  'service': 29,
#  'represent': 6,
#  'website': 3,
#  'mentioned': 14,
#  'europe': 96,
#  'direct': 9,
#  'initiative': 11,
#  'provide': 34,
#  'useful': 5,
#  'information': 46,
#  'possibly': 8,
#  'avoid': 8,
#  'need': 125,
#  'indeed': 29,
#  'confirm': 7,
#  'appropriate': 15,
#  'vehicle': 3,
#  'become': 21,
#  'importance': 25,
#  'relevance': 1,
#  'aim': 13,
#  'individuals': 5,
#  'civil': 23,
#  'society': 21,
#  'generally': 5,
#  'individual': 17,
#  'resident': 3,
#  'feel': 20,
#  'principles': 11,
#  'being': 62,
#  'applied': 13,
#  'whatever': 5,
#  'considered': 12,
#  'admissible': 2,
#  'mention': 10,
#  'just': 69,
#  'demonstrate': 3,
#  'range': 4,
#  'topics': 3,
#  'potential': 6,
#  'effectiveness': 5,
#  'mechanism': 10,
#  'petitioner': 1,
#  'succeeded': 1,
#  'getting': 1,
#  'teaching': 2,
#  'recognised': 8,
#  'presumably': 2,
#  'affecting': 4,
#  'salary': 5,
#  'promotion': 8,
#  'prospects': 1,
#  'spanish': 3,
#  'acting': 4,
#  'environmental': 30,
#  'association': 1,
#  'resulted': 4,
#  'infringement': 3,
#  'brought': 7,
#  'relation': 17,
#  'habitats': 1,
#  'frequent': 7,
#  'cause': 21,
#  'lasting': 3,
#  'effect': 8,
#  'valuable': 9,
#  'feedback': 2,
#  'other': 100,
#  'legislation': 22,
#  'works': 5,
#  'benefit': 10,
#  'without': 33,
#  'numerous': 5,
#  'officials': 6,
#  'investigate': 3,
#  'instigate': 1,
#  'thanks': 8,
#  'rapid': 3,
#  'equally': 5,
#  'committed': 4,
#  'response': 12,
#  'replying': 1,
#  'requests': 4,
#  'explanation': 11,
#  'dealing': 5,
#  'taken': 54,
#  'reply': 11,
#  'letter': 8,
#  'unusual': 2,
#  'why': 51,
#  'recommending': 2,
#  'relevant': 11,
#  'permanent': 2,
#  'meetings': 2,
#  'develop': 6,
#  'greater': 32,
#  'understanding': 4,
#  'problems': 49,
#  'face': 9,
#  'respond': 8,
#  'here': 53,
#  'improve': 27,
#  'overall': 9,
#  'mechanisms': 6,
#  'ideas': 8,
#  'others': 28,
#  'appear': 7,
#  'kessler': 1,
#  'proposing': 4,
#  'database': 1,
#  'petitioners': 3,
#  'track': 2,
#  'progress': 31,
#  'lie': 2,
#  'trust': 4,
#  'bear': 5,
#  'mind': 10,
#  'proposal': 38,
#  'various': 22,
#  'call': 30,
#  'often': 25,
#  'opinion': 36,
#  'certain': 44,
#  'areas': 36,
#  'concern': 34,
#  'arisen': 1,
#  'preparing': 4,
#  'particular': 45,
#  'social': 84,
#  'security': 28,
#  'consumer': 14,
#  'protection': 45,
#  'institute': 1,
#  'style': 2,
#  'system': 45,
#  'specific': 36,
#  'keen': 2,
#  'establish': 14,
#  'links': 4,
#  'view': 55,
#  'exchanging': 1,
#  'consider': 23,
#  'empowering': 1,
#  'tool': 2,
#  'democracy': 20,
#  'remote': 5,
#  'anonymous': 1,
#  'value': 8,
#  'whole': 32,
#  'commend': 3,
#  'commissioner': 56,
#  'characterised': 2,
#  'crises': 3,
#  'eu': 52,
#  'immense': 1,
#  'distrust': 2,
#  'integration': 9,
#  'legitimate': 7,
#  'actively': 2,
#  'participate': 3,
#  'dialogue': 22,
#  'real': 30,
#  'opinions': 3,
#  'seriously': 11,
#  'task': 14,
#  'course': 61,
#  'according': 23,
#  'request': 20,
#  'gave': 7,
#  'definition': 8,
#  'term': 10,
#  'occur': 4,
#  'when': 87,
#  'fails': 5,
#  'accordance': 7,
#  'rule': 14,
#  'principle': 36,
#  'binding': 6,
#  'upon': 18,
#  'apply': 13,
#  'now': 85,
#  'future': 37,
#  'activity': 8,
#  'stresses': 4,
#  'involves': 7,
#  'inspect': 2,
#  'interpreted': 3,
#  'irrespective': 2,
#  'charter': 13,
#  'fundamental': 25,
#  'expression': 6,
#  'common': 29,
#  'constitutional': 5,
#  'traditions': 3,
#  'shall': 15,
#  'respected': 6,
#  'observes': 1,
#  'ought': 12,
#  'play': 13,
#  'implementing': 9,
#  'clear': 34,
#  'fact': 79,
#  'give': 38,
#  'opposite': 6,
#  'both': 46,
#  'code': 6,
#  'administrative': 18,
#  'heard': 5,
#  'prompt': 3,
#  'answers': 1,
#  'replies': 3,
#  'supported': 12,
#  'reasons': 17,
#  'aspects': 17,
#  'prerequisites': 1,
#  'active': 12,
#  'citizenship': 4,
#  'regain': 2,
#  'confidence': 10,
#  'make': 72,
#  'instead': 7,
#  'passive': 1,
#  'create': 19,
#  'conditions': 29,
#  'whereas': 6,
#  'undermine': 5,
#  'categories': 2,
#  'incomplete': 3,
#  'refused': 5,
#  'delays': 50,
#  'discrimination': 15,
#  'lack': 26,
#  'defence': 8,
#  'conclusions': 13,
#  'ever': 19,
#  'increasing': 8,
#  'nature': 9,
#  'renowned': 3,
#  'wider': 4,
#  'lot': 12,
#  'praise': 3,
#  'completed': 2,
#  'few': 41,
#  'having': 16,
#  'allows': 3,
#  'tirelessly': 1,
#  'transparency': 22,
#  'longer': 16,
#  'possible': 45,
#  'data': 7,
#  'secrecy': 5,
#  'used': 29,
#  'prevent': 12,
#  'scrutiny': 2,
#  'step': 14,
#  'developed': 10,
#  'endeavoured': 2,
#  'gained': 2,
#  'corresponding': 1,
#  'candidate': 8,
#  'substantial': 3,
#  'reason': 30,
#  'making': 26,
#  'financial': 33,
#  'available': 20,
#  'investigations': 5,
#  'requires': 11,
#  'independent': 12,
#  'decision': 23,
#  'big': 4,
#  'difficult': 18,
#  'receives': 1,
#  'speakers': 6,
#  'rightly': 9,
#  'restricted': 6,
#  'draftsman': 1,
#  'residence': 3,
#  'area': 38,
#  'free': 17,
#  'movement': 15,
#  'basic': 14,
#  'freedoms': 4,
#  'achieved': 10,
#  'maastricht': 4,
#  'general': 41,
#  'adequate': 14,
#  'means': 47,
#  'subsistence': 1,
#  'health': 52,
#  'insurance': 3,
#  'freedom': 15,
#  'practice': 20,
#  'comes': 8,
#  'slow': 6,
#  'transpose': 2,
#  'b': 56,
#  'arise': 2,
#  'recognition': 6,
#  'diplomas': 2,
#  'qualifications': 3,
#  'professions': 1,
#  'c': 19,
#  'standardised': 1,
#  'eg': 1,
#  'complicated': 3,
#  'forms': 4,
#  'refund': 1,
#  'medical': 3,
#  'costs': 17,
#  'analysis': 4,
#  'between': 91,
#  'shows': 4,
#  'link': 11,
#  'before': 38,
#  'court': 9,
#  'justice': 14,
#  'unfortunately': 17,
#  'ignores': 1,
#  'communications': 5,
#  'violations': 1,
#  'negative': 8,
#  'devote': 2,
#  'complain': 3,
#  'invention': 1,
#  'put': 53,
#  'concerns': 14,
#  'roman': 1,
#  'emperor': 1,
#  'always': 26,
#  'danger': 4,
#  'abolished': 5,
#  'infallible': 1,
#  'discrepancy': 1,
#  'provisions': 12,
#  'gauge': 2,
#  'legislator': 2,
#  'levels': 10,
#  'population': 19,
#  'hamsters': 1,
#  'industrial': 5,
#  'ban': 11,
#  'silicon': 1,
#  'implants': 1,
#  'introduction': 8,
#  'heavy': 1,
#  'goods': 9,
#  'tax': 12,
#  'turn': 17,
#  'congratulates': 2,
#  'accomplished': 1,
#  ...}

# %%
with open('C:/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/ngram_langid_files/English.bigram.pickle', 'rb') as handle:
    bigram_english_dict = pickle.load(handle)
bigram_english_dict
# Out:
# {'_ approval': 1,
#  'approval of': 3,
#  'of the': 906,
#  'the minutes': 6,
#  'minutes of': 2,
#  'the previous': 9,
#  'previous sitting': 2,
#  'sitting the': 1,
#  'of yesterday': 2,
#  'yesterday s': 5,
#  's sitting': 1,
#  'sitting have': 1,
#  'have been': 65,
#  'been distributed': 1,
#  'distributed are': 1,
#  'are there': 5,
#  'there any': 1,
#  'any comments': 1,
#  'comments mr': 1,
#  'mr president': 192,
#  'president on': 8,
#  'on monday': 10,
#  'monday i': 1,
#  'i made': 1,
#  'made a': 3,
#  'a point': 8,
#  'point of': 17,
#  'of order': 6,
#  'order about': 1,
#  'about president': 1,
#  'president nicole': 1,
#  'nicole fontaine': 1,
#  'fontaine s': 1,
#  's reported': 1,
#  'reported comments': 1,
#  'comments in': 1,
#  'in the': 442,
#  'the british': 9,
#  'british press': 1,
#  'press regarding': 1,
#  'regarding her': 1,
#  'her recent': 1,
#  'recent visit': 2,
#  'visit with': 1,
#  'with her': 2,
#  'her majesty': 1,
#  'majesty queen': 1,
#  'queen elizabeth': 1,
#  'elizabeth ii': 1,
#  'ii a': 1,
#  'a british': 1,
#  'british labour': 1,
#  'labour member': 1,
#  'member of': 11,
#  'of this': 79,
#  'this house': 32,
#  'house mr': 4,
#  'mr miller': 2,
#  'miller repeated': 1,
#  'repeated what': 1,
#  'what were': 1,
#  'were purported': 1,
#  'purported to': 1,
#  'to be': 176,
#  'be the': 18,
#  'the queen': 2,
#  'queen s': 1,
#  's remarks': 1,
#  'remarks not': 1,
#  'not once': 1,
#  'once but': 1,
#  'but three': 1,
#  'three times': 1,
#  'times on': 1,
#  'monday on': 1,
#  'on tuesday': 6,
#  'tuesday and': 1,
#  'and on': 6,
#  'on wednesday': 2,
#  'wednesday he': 1,
#  'he sought': 1,
#  'sought to': 1,
#  'to drag': 1,
#  'drag the': 1,
#  'queen into': 1,
#  'into a': 10,
#  'a political': 7,
#  'political controversy': 1,
#  'controversy and': 1,
#  'and to': 36,
#  'to use': 11,
#  'use her': 1,
#  'her name': 1,
#  'name to': 2,
#  'to score': 1,
#  'score cheap': 1,
#  'cheap political': 1,
#  'political points': 1,
#  'points mr': 1,
#  'president it': 4,
#  'it may': 9,
#  'may be': 16,
#  'be that': 4,
#  'that president': 1,
#  'president fontaine': 1,
#  'fontaine was': 1,
#  'was unfamiliar': 1,
#  'unfamiliar with': 1,
#  'with the': 148,
#  'british rules': 1,
#  'rules of': 11,
#  'of protocol': 1,
#  'protocol which': 1,
#  'which obtain': 1,
#  'obtain in': 1,
#  'in such': 8,
#  'such matters': 1,
#  'matters but': 1,
#  'but mr': 1,
#  'miller has': 1,
#  'has no': 4,
#  'no such': 2,
#  'such excuse': 1,
#  'excuse he': 1,
#  'he knows': 3,
#  'knows perfectly': 3,
#  'perfectly well': 3,
#  'well that': 5,
#  'that ours': 1,
#  'ours is': 2,
#  'is a': 120,
#  'a non': 8,
#  'non political': 1,
#  'political head': 1,
#  'head of': 9,
#  'of state': 3,
#  'state he': 1,
#  'that for': 3,
#  'for nearly': 1,
#  'nearly fifty': 1,
#  'fifty years': 2,
#  'years she': 1,
#  'she has': 10,
#  'has scrupulously': 1,
#  'scrupulously avoided': 1,
#  'avoided engaging': 1,
#  'engaging in': 1,
#  'in controversial': 1,
#  'controversial political': 1,
#  'political issues': 2,
#  'issues he': 1,
#  'that she': 7,
#  'she can': 1,
#  'can not': 50,
#  'not come': 3,
#  'come to': 5,
#  'to this': 31,
#  'house to': 5,
#  'to set': 5,
#  'set the': 2,
#  'the record': 3,
#  'record straight': 1,
#  'straight his': 1,
#  'his behaviour': 1,
#  'behaviour is': 2,
#  'a disgrace': 1,
#  'disgrace and': 1,
#  'and a': 18,
#  'a scandal': 1,
#  'scandal mr': 1,
#  'president i': 68,
#  'i am': 76,
#  'am proud': 1,
#  'proud to': 1,
#  'be british': 1,
#  'british but': 1,
#  'but today': 1,
#  'today i': 2,
#  'am ashamed': 1,
#  'ashamed to': 1,
#  'to share': 2,
#  'share my': 1,
#  'my nationality': 1,
#  'nationality with': 1,
#  'with that': 2,
#  'that man': 1,
#  'man has': 1,
#  'has he': 3,
#  'he no': 3,
#  'no shame': 1,
#  'shame has': 1,
#  'no respect': 1,
#  'respect has': 1,
#  'no decency': 1,
#  'decency or': 1,
#  'or honour': 1,
#  'honour at': 1,
#  'at all': 11,
#  'all mr': 2,
#  'i wish': 18,
#  'wish to': 29,
#  'use this': 3,
#  'this point': 10,
#  'order to': 56,
#  'to speak': 6,
#  'speak in': 1,
#  'in my': 24,
#  'my capacity': 1,
#  'capacity as': 3,
#  'as chairman': 1,
#  'chairman of': 7,
#  'the delegation': 3,
#  'delegation for': 1,
#  'for relations': 1,
#  'relations with': 6,
#  'the countries': 6,
#  'countries of': 5,
#  'of central': 2,
#  'central america': 2,
#  'america and': 3,
#  'and mexico': 1,
#  'mexico as': 1,
#  'as you': 13,
#  'you will': 6,
#  'will be': 56,
#  'be aware': 3,
#  'aware elections': 1,
#  'elections were': 1,
#  'were held': 1,
#  'held in': 3,
#  'in mexico': 1,
#  'mexico last': 1,
#  'last sunday': 1,
#  'sunday yesterday': 1,
#  'yesterday the': 4,
#  'delegation which': 1,
#  'which i': 17,
#  'i chair': 1,
#  'chair met': 1,
#  'met and': 1,
#  'and discussed': 1,
#  'discussed a': 1,
#  'a report': 9,
#  'report drawn': 2,
#  'drawn up': 4,
#  'up by': 4,
#  'by our': 6,
#  'our fellow': 7,
#  'fellow members': 8,
#  'members who': 6,
#  'who had': 1,
#  'had been': 4,
#  'been to': 1,
#  'to mexico': 1,
#  'mexico to': 1,
#  'to act': 6,
#  'act as': 4,
#  'as observers': 1,
#  'observers at': 1,
#  'at these': 1,
#  'these elections': 1,
#  'elections on': 1,
#  'on behalf': 85,
#  'behalf of': 85,
#  'this parliament': 15,
#  'parliament mr': 3,
#  'i would': 147,
#  'would ask': 20,
#  'ask you': 16,
#  'you to': 16,
#  'to see': 24,
#  'see if': 1,
#  'if the': 24,
#  'the president': 12,
#  'president of': 10,
#  'parliament could': 1,
#  'could forward': 1,
#  'forward our': 1,
#  'our resolution': 7,
#  'resolution the': 3,
#  'the complete': 1,
#  'complete text': 1,
#  'text of': 5,
#  'of which': 13,
#  'which you': 3,
#  'will receive': 1,
#  'receive today': 1,
#  'today to': 1,
#  'to the': 331,
#  'the mexican': 1,
#  'mexican authorities': 1,
#  'authorities mr': 1,
#  'president ladies': 16,
#  'ladies and': 33,
#  'and gentlemen': 33,
#  'gentlemen i': 9,
#  'i want': 7,
#  'want to': 30,
#  'to draw': 7,
#  'draw your': 3,
#  'your attention': 7,
#  'attention to': 13,
#  'to something': 2,
#  'something really': 1,
#  'really annoying': 1,
#  'annoying in': 1,
#  'in connection': 3,
#  'connection with': 4,
#  'minutes the': 1,
#  'the x': 2,
#  'x texts': 1,
#  'texts adopted': 1,
#  'adopted x': 1,
#  'x also': 2,
#  'also form': 1,
#  'form part': 1,
#  'part of': 33,
#  'minutes i': 1,
#  'i pointed': 1,
#  'pointed out': 11,
#  'out yesterday': 1,
#  'yesterday during': 1,
#  'during the': 23,
#  'the vote': 35,
#  'vote on': 21,
#  'on the': 299,
#  'the directive': 41,
#  'directive to': 1,
#  'to combat': 6,
#  'combat money': 1,
#  'money laundering': 1,
#  'laundering the': 1,
#  'the english': 6,
#  'english translation': 3,
#  'translation of': 1,
#  'of article': 3,
#  'article needs': 1,
#  'needs to': 15,
#  'be corrected': 2,
#  'corrected to': 1,
#  'to bring': 13,
#  'bring it': 2,
#  'it in': 8,
#  'in line': 6,
#  'line with': 7,
#  'with amendment': 1,
#  'amendment no': 11,
#  'no because': 1,
#  'because the': 22,
#  'translation is': 1,
#  'is wrong': 3,
#  'wrong in': 2,
#  'the middle': 3,
#  'middle of': 2,
#  'the second': 7,
#  'second paragraph': 1,
#  'paragraph of': 4,
#  'english version': 1,
#  'version there': 1,
#  'there is': 89,
#  'is only': 6,
#  'only a': 9,
#  'a reference': 2,
#  'reference to': 5,
#  'to representation': 1,
#  'representation in': 1,
#  'in legal': 1,
#  'legal proceedings': 3,
#  'proceedings but': 1,
#  'but no': 2,
#  'no reference': 2,
#  'to legal': 1,
#  'legal consultants': 1,
#  'consultants as': 1,
#  'as there': 5,
#  'is in': 21,
#  'the german': 3,
#  'german text': 2,
#  'text that': 2,
#  'that is': 75,
#  'a key': 3,
#  'key point': 1,
#  'point in': 6,
#  'in this': 99,
#  'this directive': 7,
#  'directive and': 12,
#  'and since': 3,
#  'since the': 10,
#  'the council': 57,
#  'council working': 1,
#  'working group': 3,
#  'group is': 6,
#  'is working': 2,
#  'working on': 1,
#  'the basis': 16,
#  'basis of': 14,
#  'english text': 1,
#  'text it': 1,
#  'it is': 289,
#  'is quite': 6,
#  'quite crucial': 1,
#  'crucial to': 4,
#  'to correct': 2,
#  'correct this': 2,
#  'this text': 10,
#  'text i': 1,
#  'i had': 4,
#  'had already': 1,
#  'already complained': 1,
#  'complained about': 2,
#  'about this': 8,
#  'this in': 10,
#  'in committee': 5,
#  'committee vis': 1,
#  'vis a': 2,
#  'a vis': 2,
#  'vis the': 2,
#  'the language': 1,
#  'language services': 1,
#  'services at': 2,
#  'at the': 92,
#  'the time': 15,
#  'time the': 8,
#  'the committee': 86,
#  'committee decided': 1,
#  'decided not': 1,
#  'not to': 16,
#  'to table': 1,
#  'table an': 1,
#  'an amendment': 5,
#  'amendment because': 1,
#  'text is': 2,
#  'is the': 90,
#  'the original': 4,
#  'original version': 1,
#  'version as': 1,
#  'as drafted': 1,
#  'drafted by': 2,
#  'by the': 139,
#  'the rapporteur': 40,
#  'rapporteur i': 2,
#  'i complained': 1,
#  'this yesterday': 1,
#  'the situation': 36,
#  'situation was': 2,
#  'was not': 12,
#  'not remedied': 1,
#  'remedied and': 1,
#  'and today': 2,
#  'today is': 7,
#  'the third': 4,
#  'third time': 1,
#  'time i': 4,
#  'am complaining': 1,
#  'complaining about': 1,
#  'about it': 3,
#  'it i': 2,
#  'i do': 28,
#  'do think': 2,
#  'think the': 2,
#  'the services': 5,
#  'services of': 1,
#  'house should': 1,
#  'should work': 2,
#  'work more': 1,
#  'more carefully': 1,
#  'carefully on': 1,
#  'on such': 2,
#  'such key': 1,
#  'key questions': 1,
#  'questions and': 2,
#  'and it': 30,
#  'it really': 4,
#  'really is': 5,
#  'is intolerable': 1,
#  'intolerable that': 1,
#  'that despite': 2,
#  'despite my': 1,
#  'my criticism': 1,
#  'criticism yesterday': 1,
#  'minutes have': 1,
#  'have got': 1,
#  'got the': 2,
#  'the text': 14,
#  'text wrong': 1,
#  'wrong again': 1,
#  'again i': 1,
#  'you get': 1,
#  'get to': 3,
#  'the bottom': 2,
#  'bottom of': 2,
#  'this matter': 18,
#  'matter to': 1,
#  'to sort': 2,
#  'sort out': 2,
#  'out this': 3,
#  'this most': 2,
#  'most important': 12,
#  'important aspect': 1,
#  'aspect of': 3,
#  'to please': 1,
#  'please correct': 1,
#  'translation mr': 1,
#  'president yesterday': 1,
#  'yesterday we': 1,
#  'we received': 3,
#  'received a': 2,
#  'a communication': 2,
#  'communication on': 4,
#  'on yellow': 1,
#  'yellow paper': 1,
#  'paper from': 1,
#  'from the': 65,
#  'the vice': 5,
#  'vice president': 15,
#  'president with': 2,
#  'with some': 3,
#  'some nuts': 1,
#  'nuts attached': 1,
#  'attached to': 2,
#  'to it': 2,
#  'it this': 3,
#  'this note': 1,
#  'note was': 1,
#  'was about': 1,
#  'about supporting': 1,
#  'supporting the': 4,
#  'the export': 1,
#  'export of': 1,
#  'of products': 1,
#  'products from': 1,
#  'from vanuatu': 1,
#  'vanuatu a': 1,
#  'a developing': 1,
#  'developing country': 1,
#  'country in': 4,
#  'the pacific': 2,
#  'pacific i': 1,
#  'i think': 22,
#  'think that': 17,
#  'a very': 34,
#  'very good': 9,
#  'good idea': 4,
#  'idea and': 2,
#  'and quite': 1,
#  'quite right': 2,
#  'right and': 2,
#  'and i': 64,
#  'am quite': 1,
#  'quite happy': 1,
#  'happy to': 2,
#  'to support': 14,
#  'support it': 4,
#  'it but': 4,
#  'but what': 4,
#  'what rather': 1,
#  'rather puzzles': 1,
#  'puzzles me': 1,
#  'me is': 2,
#  'is that': 33,
#  'that in': 34,
#  'in it': 5,
#  'it the': 10,
#  'president quite': 1,
#  'quite explicitly': 1,
#  'explicitly stated': 1,
#  'stated that': 2,
#  'that it': 48,
#  'is illegal': 1,
#  'illegal to': 1,
#  'to import': 1,
#  'import these': 1,
#  'these nuts': 2,
#  'nuts into': 1,
#  'into the': 19,
#  'the european': 238,
#  'european union': 94,
#  'union so': 1,
#  'so i': 14,
#  'i must': 14,
#  'must ask': 2,
#  'ask this': 1,
#  'this vice': 1,
#  'president to': 6,
#  'to explain': 4,
#  'explain how': 1,
#  'how these': 2,
#  'nuts came': 1,
#  'came to': 2,
#  'be illegally': 1,
#  'illegally imported': 1,
#  'imported since': 1,
#  'since it': 5,
#  'it was': 34,
#  'was he': 1,
#  'he who': 1,
#  'who delivered': 1,
#  'delivered them': 1,
#  'them to': 17,
#  'to us': 15,
#  'us that': 10,
#  'in itself': 3,
#  'itself is': 2,
#  'a contradiction': 1,
#  'contradiction so': 1,
#  'so would': 1,
#  'would he': 2,
#  'he please': 1,
#  'please clarify': 1,
#  'clarify the': 1,
#  'the matter': 17,
#  'matter laughter': 1,
#  'laughter and': 1,
#  'and applause': 1,
#  'applause the': 1,
#  'minutes were': 1,
#  'were approved': 1,
#  'approved welcome': 1,
#  'welcome committee': 1,
#  'committee on': 73,
#  'on petitions': 35,
#  'petitions european': 1,
#  'european ombudsman': 16,
#  'ombudsman the': 4,
#  'the next': 25,
#  'next item': 12,
#  'item is': 11,
#  'the joint': 16,
#  'joint debate': 8,
#  'debate on': 15,
#  'the following': 10,
#  'following reports': 1,
#  'reports tabled': 1,
#  'tabled on': 1,
#  'petitions a': 2,
#  'a by': 18,
#  'by mrs': 30,
#  'mrs lambert': 12,
#  'lambert on': 4,
#  'the deliberations': 2,
#  'deliberations of': 2,
#  'petitions during': 2,
#  'the parliamentary': 5,
#  'parliamentary year': 2,
#  'year a': 2,
#  'mrs thors': 10,
#  'thors on': 2,
#  'the annual': 8,
#  'annual report': 10,
#  'report on': 28,
#  'the activities': 5,
#  'activities of': 5,
#  'ombudsman in': 6,
#  'in mr': 2,
#  'am glad': 2,
#  'glad to': 1,
#  'to have': 27,
#  'have the': 23,
#  'the opportunity': 8,
#  'opportunity to': 17,
#  'to address': 11,
#  'address the': 6,
#  'european parliament': 58,
#  'parliament concerning': 1,
#  'concerning the': 4,
#  'the results': 9,
#  'results of': 6,
#  'of my': 11,
#  'my work': 1,
#  'work as': 6,
#  'as european': 1,
#  'the year': 13,
#  'year the': 10,
#  'report for': 4,
#  'for covers': 1,
#  'covers the': 1,
#  'the last': 20,
#  'last year': 16,
#  'year of': 3,
#  'the first': 18,
#  'first mandate': 1,
#  'mandate of': 2,
#  'ombudsman last': 2,
#  'the ombudsman': 83,
#  'ombudsman s': 25,
#  's office': 6,
#  'office received': 1,
#  'received new': 1,
#  'new complaints': 1,
#  'complaints compared': 1,
#  'compared to': 4,
#  'to in': 4,
#  'in an': 17,
#  'an increase': 5,
#  'increase of': 3,
#  'of nearly': 1,
#  'nearly the': 1,
#  'the number': 19,
#  'number of': 65,
#  'of inquiries': 1,
#  'inquiries opened': 1,
#  'opened rose': 1,
#  'rose from': 1,
#  'from in': 3,
#  'in to': 5,
#  'of over': 1,
#  'over as': 1,
#  'as well': 27,
#  'well as': 21,
#  'as becoming': 1,
#  'becoming better': 1,
#  'better known': 2,
#  'known the': 1,
#  'ombudsman is': 7,
#  'is also': 29,
#  'also attracting': 1,
#  'attracting a': 1,
#  'a higher': 2,
#  'higher proportion': 1,
#  'proportion of': 5,
#  'of serious': 2,
#  'serious complaints': 1,
#  'complaints which': 1,
#  'which require': 1,
#  'require full': 1,
#  'full investigation': 1,
#  'investigation you': 1,
#  'you may': 2,
#  'be interested': 2,
#  'interested to': 2,
#  'to know': 6,
#  'know that': 17,
#  'that the': 208,
#  'the same': 46,
#  'same trend': 2,
#  'trend has': 1,
#  'has continued': 2,
#  'continued to': 4,
#  'the present': 16,
#  'present year': 1,
#  'year during': 1,
#  'first six': 1,
#  'six months': 3,
#  'months of': 2,
#  'this year': 11,
#  'of new': 5,
#  'new inquiries': 1,
#  'inquiries rose': 1,
#  'rose by': 1,
#  'by over': 1,
#  'over the': 23,
#  'same period': 2,
#  'period in': 4,
#  'in inquiries': 1,
#  'inquiries are': 1,
#  'are the': 15,
#  'the most': 28,
#  'most resource': 1,
#  'resource intensive': 1,
#  'intensive aspect': 1,
#  's work': 5,
#  'work it': 2,
#  'is therefore': 16,
#  'therefore a': 4,
#  'a great': 16,
#  'great challenge': 1,
#  'challenge to': 1,
#  'to deal': 11,
#  'deal with': 14,
#  'with this': 15,
#  'this increase': 1,
#  'increase whilst': 1,
#  'whilst maintaining': 1,
#  'maintaining the': 3,
#  'the quality': 7,
#  'quality of': 10,
#  'of our': 40,
#  'our work': 6,
#  'work and': 3,
#  'and meeting': 1,
#  'meeting our': 1,
#  'our target': 1,
#  'target of': 1,
#  'of closing': 1,
#  'closing most': 1,
#  'most inquiries': 1,
#  'inquiries within': 1,
#  'within one': 1,
#  'one year': 2,
#  'year i': 4,
#  'do hope': 1,
#  'hope that': 20,
#  'parliament will': 7,
#  'will support': 4,
#  'support the': 20,
#  'in seeking': 1,
#  'seeking the': 1,
#  'the resources': 5,
#  'resources needed': 1,
#  'needed to': 4,
#  'to carry': 2,
#  'carry out': 5,
#  'out the': 9,
#  'the work': 31,
#  'work effectively': 3,
#  'effectively during': 1,
#  'during we': 1,
#  'we continued': 1,
#  'to receive': 6,
#  'receive a': 3,
#  'a quite': 1,
#  'quite high': 1,
#  'high proportion': 1,
#  'of complaints': 8,
#  'complaints over': 1,
#  'over which': 1,
#  'which lay': 1,
#  'lay outside': 1,
#  'outside the': 7,
#  'the mandate': 4,
#  'the proportion': 1,
#  'the complaints': 7,
#  'complaints outside': 1,
#  'mandate even': 1,
#  'even increased': 1,
#  'increased slightly': 1,
#  'slightly probably': 1,
#  'probably because': 1,
#  'because we': 15,
#  'a growing': 2,
#  'growing number': 2,
#  'complaints by': 2,
#  'by e': 5,
#  'e mail': 6,
#  'mail we': 1,
#  'we gladly': 1,
#  'gladly accept': 1,
#  'accept complaints': 1,
#  'mail and': 1,
#  'and many': 9,
#  'many of': 8,
#  'of them': 11,
#  'them contain': 1,
#  'contain well': 1,
#  'well presented': 1,
#  'presented allegations': 1,
#  'allegations of': 1,
#  'of maladministration': 3,
#  'maladministration however': 1,
#  'however in': 2,
#  'in all': 10,
#  'all more': 1,
#  'more of': 2,
#  'the e': 1,
#  'mail complaints': 1,
#  'complaints are': 2,
#  'are directed': 1,
#  'directed against': 2,
#  'against authorities': 1,
#  'authorities of': 2,
#  'of member': 3,
#  'member states': 87,
#  'states during': 3,
#  'the campaign': 3,
#  'campaign for': 1,
#  'for the': 188,
#  'the election': 1,
#  'election of': 1,
#  'of a': 73,
#  'a european': 17,
#  'year some': 2,
#  'some critical': 1,
#  'critical voices': 1,
#  'voices suggested': 1,
#  'suggested that': 1,
#  's mandate': 1,
#  'mandate should': 1,
#  'should be': 58,
#  'be broadened': 1,
#  'broadened to': 1,
#  'to include': 4,
#  'include complaints': 1,
#  'complaints against': 3,
#  'against member': 1,
#  'states in': 8,
#  'in cases': 3,
#  'cases where': 2,
#  'where a': 1,
#  'a question': 4,
#  'question of': 13,
#  'of european': 25,
#  'union law': 3,
#  'law is': 2,
#  'is involved': 4,
#  'involved i': 2,
#  'am not': 8,
#  'not sure': 2,
#  'sure whether': 2,
#  'whether they': 3,
#  'they understood': 1,
#  'understood that': 1,
#  'that this': 51,
#  'this would': 8,
#  'would mean': 4,
#  'mean the': 2,
#  'ombudsman carrying': 1,
#  'carrying out': 6,
#  'out tasks': 1,
#  'tasks currently': 1,
#  'currently belonging': 1,
#  'belonging to': 1,
#  'european commission': 15,
#  'commission as': 5,
#  'as the': 73,
#  'the guardian': 1,
#  'guardian of': 1,
#  'the treaty': 13,
#  'treaty and': 3,
#  'parliament as': 2,
#  'the democratic': 2,
#  'democratic forum': 1,
#  'forum to': 1,
#  'to which': 11,
#  'which citizens': 1,
#  'citizens may': 2,
#  'may address': 1,
#  'address petitions': 1,
#  'petitions we': 2,
#  'we study': 1,
#  'study carefully': 1,
#  'carefully all': 1,
#  'all the': 51,
#  'complaints we': 2,
#  'we receive': 4,
#  'receive especially': 1,
#  'especially if': 2,
#  'if they': 15,
#  'they involve': 1,
#  'involve rights': 1,
#  'rights under': 2,
#  'under european': 2,
#  'law in': 4,
#  'in we': 2,
#  'we managed': 1,
#  'managed to': 6,
#  'to advise': 1,
#  'advise the': 1,
#  'the complainant': 3,
#  'complainant or': 1,
#  'or transfer': 1,
#  'transfer the': 1,
#  'the complaint': 2,
#  'complaint to': 2,
#  'to a': 44,
#  'a competent': 1,
#  'competent body': 1,
#  'body in': 1,
#  'in about': 1,
#  'about half': 1,
#  'half of': 1,
#  'the cases': 2,
#  'cases of': 5,
#  'of these': 23,
#  'these we': 1,
#  'we transferred': 1,
#  'transferred cases': 1,
#  'cases to': 1,
#  'parliament to': 15,
#  'be dealt': 5,
#  'dealt with': 7,
#  'with as': 2,
#  'as petitions': 2,
#  'petitions and': 9,
#  'and advised': 1,
#  'advised a': 1,
#  'a further': 4,
#  'further complainants': 1,
#  'complainants of': 1,
#  'of their': 26,
#  'their rights': 5,
#  'rights to': 3,
#  'to petition': 2,
#  'petition the': 2,
#  'parliament in': 6,
#  'in many': 6,
#  'many cases': 5,
#  'cases complaints': 1,
#  'against national': 1,
#  'national regional': 1,
#  'regional or': 1,
#  'or local': 1,
#  'local authorities': 3,
#  'authorities could': 1,
#  'could be': 13,
#  'with effectively': 1,
#  'effectively by': 1,
#  'by an': 7,
#  'an ombudsman': 5,
#  'the member': 44,
#  'states concerned': 1,
#  ...}

# %%
bigram_english_dict.get('of the')
# Out:
# 906

# %%
import operator
english_unigram_freqs = sorted(unigram_english_dict.items(), key=operator.itemgetter(1), reverse=True)
english_unigram_freqs[:10]
# Out:
# [('the', 5699),
#  ('of', 2769),
#  ('to', 2490),
#  ('and', 2040),
#  ('in', 1668),
#  ('a', 1343),
#  ('is', 1303),
#  ('that', 1205),
#  ('this', 887),
#  ('on', 865)]

# %%
labels, values = zip(*english_unigram_freqs[:10])
indexes = arange(len(labels))
width = 0.8 # width = 1 would give bars that overlap because they are too close.

fig = plt.figure(figsize=(10,7))                                                               
ax = fig.gca() # Get current axis
rects = ax.bar(indexes, values, width)

# Add title and axis labels
fig.suptitle('Top 10 English word unigrams', fontsize=20)
plt.xlabel('Word unigram', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Display value of each bar on bar
for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() / 2., 50 + height, '%d' % int(height), ha='center', va='bottom') # Can also add color and fontweight arguments.

# Remove the default x-axis tick numbers and use tick numbers of your own choosing:
ax.set_xticks(indexes)
# Replace the tick numbers with strings:
ax.set_xticklabels(labels)

plt.show()
# plt.savefig('top10EnglishWordUnigrams.png')

# %% [markdown]
# ## 1. Generating unigram and bigram frequencies for English, French and Italian from training files

# %%
def get_ngram_count_dict(tokens, n):
    if n == 1:
        n_grams = ngrams(tokens, n)
    else:
        n_grams = ngrams(tokens, n, pad_left=True, pad_right=True, left_pad_symbol='_', right_pad_symbol='_') # Fun fact: If I remove padding here and later when testing, and also remove the '_' from the unigram dicts, the accuracy rises slightly. However, it's not statistically significant due to the small size of the data.
    fdist = FreqDist(n_grams)
    ngram_dict = dict()
    for k,v in fdist.items():
        ngram_dict[' '.join(k)] = v
    return ngram_dict

# Calls get_ngram_count_dict to get a unigram and bigram dict from file.
def get_unigram_bigram_dicts(file):
    with open(file, encoding='utf8') as f:
        content = f.read()
    tokens = ultimate_tokenize(content)
    unigram_dict = get_ngram_count_dict(tokens, 1)     
    bigram_dict = get_ngram_count_dict(tokens, 2)     
    return unigram_dict, bigram_dict

# Dumps unigram and bigram dictionary of training data of given language to .pickle files.
def dump_pickle(language):
    training_file = 'ngram_langid_files/LangId.train.' + language + '.txt'
    unigram_dict, bigram_dict = get_unigram_bigram_dicts(training_file)
    with open('ngram_langid_files/' + language + '.unigram.pickle', 'wb') as handle:
        pickle.dump(unigram_dict, handle, protocol=pickle.HIGHEST_PROTOCOL) # HIGHEST_PROTOCOL instructs pickle to use the highest protocol version available.
    with open('ngram_langid_files/' + language + '.bigram.pickle', 'wb') as handle:
        pickle.dump(bigram_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
dump_pickle('English')
dump_pickle('French')
dump_pickle('Italian')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\esmba\OneDrive\Documents\CodeRepos\InterviewPrepPractice\nltk\2-3-Language-Identifier-Using-Word-Bigrams.ipynb Cell 20 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=26'>27</a>     with open('ngram_langid_files/' + language + '.bigram.pickle', 'wb') as handle:
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=27'>28</a>         pickle.dump(bigram_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=29'>30</a> dump_pickle('English')
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=30'>31</a> dump_pickle('French')
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=31'>32</a> dump_pickle('Italian')
#
# c:\Users\esmba\OneDrive\Documents\CodeRepos\InterviewPrepPractice\nltk\2-3-Language-Identifier-Using-Word-Bigrams.ipynb Cell 20 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=21'>22</a> def dump_pickle(language):
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=22'>23</a>     training_file = 'ngram_langid_files/LangId.train.' + language + '.txt'
# ---> <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=23'>24</a>     unigram_dict, bigram_dict = get_unigram_bigram_dicts(training_file)
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=24'>25</a>     with open('ngram_langid_files/' + language + '.unigram.pickle', 'wb') as handle:
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=25'>26</a>         pickle.dump(unigram_dict, handle, protocol=pickle.HIGHEST_PROTOCOL) # HIGHEST_PROTOCOL instructs pickle to use the highest protocol version available.
#
# c:\Users\esmba\OneDrive\Documents\CodeRepos\InterviewPrepPractice\nltk\2-3-Language-Identifier-Using-Word-Bigrams.ipynb Cell 20 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a> def get_unigram_bigram_dicts(file):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=13'>14</a>     with open(file, encoding='utf8') as f:
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a>         content = f.read()
#      <a href='vscode-notebook-cell:/c%3A/Users/esmba/OneDrive/Documents/CodeRepos/InterviewPrepPractice/nltk/2-3-Language-Identifier-Using-Word-Bigrams.ipynb#X25sZmlsZQ%3D%3D?line=15'>16</a>     tokens = ultimate_tokenize(content)
#
# File c:\Users\esmba\miniconda3\envs\CohereInterview\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ngram_langid_files/LangId.train.English.txt'

# %% [markdown]
# Later, it will also be required to know how many sentences there are in the training data for each language. This is because of the method used to calculate probabilities (incorporating the probability of the bigram among other bigrams starting with the same word) and the fact we use padding for our bigrams.
#
# In our training data each line is a sentence, which is very convenient for calculating the number of sentences.
#
# We go ahead and get the number of sentences (for more efficiency, the following code could be added to `get_unigram_bigram_dicts`):

# %%
with open('ngram_langid_files/LangId.train.English.txt', encoding='utf8') as f:
    for i, l in enumerate(f):
        pass
number_of_sents_en = i + 1
with open('ngram_langid_files/LangId.train.French.txt', encoding='utf8') as f:
    for i, l in enumerate(f):
        pass
number_of_sents_fr = i + 1
with open('ngram_langid_files/LangId.train.Italian.txt', encoding='utf8') as f:
    for i, l in enumerate(f):
        pass
number_of_sents_it = i + 1

print('NUMBER OF SENTENCES IN TRAINING DATA')
print('English:', number_of_sents_en)
print('French:', number_of_sents_fr)
print('Italian:', number_of_sents_it)
# Out:
# NUMBER OF SENTENCES IN TRAINING DATA
# English: 2980
# French: 2980
# Italian: 2821

# %% [markdown]
# ## 2. Identifying language for each line of the test file using bigram probabilities

# %%
with open('ngram_langid_files/English.unigram.pickle', 'rb') as handle:
    unigram_english_dict = pickle.load(handle)
    
with open('ngram_langid_files/English.bigram.pickle', 'rb') as handle:
    bigram_english_dict = pickle.load(handle)
    
with open('ngram_langid_files/French.unigram.pickle', 'rb') as handle:
    unigram_french_dict = pickle.load(handle)
    
with open('ngram_langid_files/French.bigram.pickle', 'rb') as handle:
    bigram_french_dict = pickle.load(handle)
    
with open('ngram_langid_files/Italian.unigram.pickle', 'rb') as handle:
    unigram_italian_dict = pickle.load(handle)
    
with open('ngram_langid_files/Italian.bigram.pickle', 'rb') as handle:
    bigram_italian_dict = pickle.load(handle)
    
vocabulary_size = len(unigram_english_dict) + len(unigram_french_dict) + len(unigram_italian_dict)
vocabulary_size
# Out:
# 22705

# %%
# Get probability of given bigram belonging to the language which bigram_dict is in
def get_bigram_probability(bigram, first_word, bigram_dict, first_word_dict): # first_word is the first word of the word bigram.
    bigram_count = bigram_dict.get(bigram)
    if bigram_count is None:
        bigram_count = 0
    
    first_word_count = first_word_dict.get(first_word)
    if first_word_count is None:
        first_word_count = 0
    
    return (bigram_count + 1) / (first_word_count + vocabulary_size) # To get the logic of this formula, note how the proability is used in the function below. Without the + 1 in the Nr, if you find a bigram which is not in our known bigrams for a language, the probability of it being in that language would become 0. So we would like to assign a small probability of 1 / vocabulary_size in that case. Also note the arbitrariness of this 'probability'. We're saying "Given a bigram and a language, what is the probability that the bigram is of that language?" This is arbitrary because to get a meaningful probability we need to know which are the other languages considered and what their bigram frequencies are. That would be another way to do it, but arguable a worse one because it wouldn't be able to give a confidence score for a particular language. The formula just uses common sense to get to a number which works for the purposes. In the denominator, we have both first_word_count and vocabulary_size. Why? We have vocabulary_size for all langs in the denom because the larger this is, the less significant it is that for this particular language the bigram appears so many times. Could we have used a vocab_size of bigrams instead of unigrams? Sure, and the 'probabilities' would end up being much smaller numbers. What about first_word_count? This gives us a way to compare this bigram against other bigrams in this language starting with the same word. In general though, for a given bigram, it's more important to consider how many times it exists than to consider whether it is the usual bigram given a certain first word. The formula achieves that. Take the bigram 'le monseiur' and the English language. Let's say the bigram appears once and 'le' also appears once, while in French 'le monseiur' appears 100 times and le appears 100,000 times. Probability for English = (1 + 1) / (1 + 20,000) = 0.000099995. Probability for French = (100 + 1) / (100,000 + 20,000) = 0.00084166666. Note how the probability for French is still low because 100/100,000 is quite low and maybe it's not French after all if in French le is usually followed by other words. However, it's still significantly higher than the probability for English where both 'le' and 'le monseiur' only appear once.

# Get probability that a given bigram list is of a language (specified by its bigram_dict)
def get_language_probability(bigram_list, first_words, bigram_dict, first_word_dict):
    result = 1.0
    index = 0
    for bigram in bigram_list:
        result *= get_bigram_probability(bigram, first_words[index], bigram_dict, first_word_dict)
        index += 1
    return result

# Load correct solutions
solution_dict = dict()
with open('ngram_langid_files/LangId.sol.txt') as f:
    for line in f:
       (key, val) = line.split()
       solution_dict[int(key)] = val
        
line_no = 1
result_dict = dict()
correct = 0
incorrect_line_numbers = []

# This needs to be done because I'm using padding for bigrams so the unigram dicts in their raw forms can't be used in get_bigram_probability():
unigram_english_dict['_'] = number_of_sents_en
unigram_french_dict['_'] = number_of_sents_fr
unigram_italian_dict['_'] = number_of_sents_it

with open('ngram_langid_files/LangId.test.txt', encoding='utf8') as f:
    for line in f:
        tokens = ultimate_tokenize(line)
        bigrams = ngrams(tokens, 2, pad_left=True, pad_right=True, left_pad_symbol='_', right_pad_symbol='_')
        bigram_list = [] # bigram_list will be exactly like bigrams but instead of [('_', 'this'), ...] it will be ['_ this', ...]. It is required because this is how bigrams are represented in the dictionary.
        first_words = [] # The first words of each bigram. This is the similar to making a unigram_list. We use it because we don't want something in the form [(this,), ...]. Also because we want this to include '_'. We want it to include '_' because we're not using the unigrams for classification but as part of a formula to judge bigram frequency based on the starting word.
        for b in bigrams:
            bigram_list.append(' '.join(b))
            first_words.append(b[0])
        
        english_prob = get_language_probability(bigram_list, first_words, bigram_english_dict, unigram_english_dict)
        french_prob = get_language_probability(bigram_list, first_words, bigram_french_dict, unigram_french_dict)
        italian_prob = get_language_probability(bigram_list, first_words, bigram_italian_dict, unigram_italian_dict)
        
        max_prob = max(english_prob, french_prob, italian_prob)
        if max_prob == english_prob:
            result_dict[line_no] = 'English'
        elif max_prob == french_prob:
            result_dict[line_no] = 'French'
        else:
            result_dict[line_no] = 'Italian'
        
        if solution_dict[line_no] == result_dict[line_no]:
            correct += 1
        else:
            incorrect_line_numbers.append(line_no)
            
        line_no += 1

# Storing results from result_dict to file:
with open('ngram_langid_files/LangId.result.txt', 'w') as f:
    for key, val in result_dict.items():
        f.write(' '.join([str(key), val]) + '\n')
        
print('Accuracy: {:2.2f}%'.format(correct * 100 / len(solution_dict)))
# Out:
# Accuracy: 98.00%

# %%
print('Line numbers for incorrectly classified languages: {}'.format(str(incorrect_line_numbers)))
# Out:
# Line numbers for incorrectly classified languages: [24, 87, 187, 191, 247, 279]

# %% [markdown]
# ## 3. Testing with our own sentence

# %%
sent = "This is a sentence."
sent_tokens = ultimate_tokenize(sent)
sent_bigrams_pre = ngrams(sent_tokens, 2, pad_left=True, pad_right=True, left_pad_symbol='_', right_pad_symbol='_')
sent_bigrams = []
sent_bigrams_first_words = []
for b in sent_bigrams_pre:
    sent_bigrams.append(' '.join(b))
    sent_bigrams_first_words.append(b[0])
print('Sentence bigrams:', sent_bigrams)
print('Sentence bigrams first words:', sent_bigrams_first_words)
# Out:
# Sentence bigrams: ['_ this', 'this is', 'is a', 'a sentence', 'sentence _']
# Sentence bigrams first words: ['_', 'this', 'is', 'a', 'sentence']

# %%
sent_english_prob = get_language_probability(sent_bigrams, sent_bigrams_first_words, bigram_english_dict, unigram_english_dict)
sent_french_prob = get_language_probability(sent_bigrams, sent_bigrams_first_words, bigram_french_dict, unigram_french_dict)
sent_italian_prob = get_language_probability(sent_bigrams, sent_bigrams_first_words, bigram_italian_dict, unigram_italian_dict)
print("RAW 'PROBABILITIES'")
print('English:', sent_english_prob)
print('French:', sent_french_prob)
print('Italian:', sent_italian_prob)
# As we can see, these 'probabilities' are arbitrary. We can try to convert them to percentages since we are classifying only among these 3 languages:
# Out:
# RAW 'PROBABILITIES'
# English: 1.6907852103961136e-18
# French: 1.4294173998895933e-22
# Italian: 1.4086603160283195e-22

# %%
def get_normalized_probabilities(list_of_probabilities):
    sum_of_probabilities = sum(list_of_probabilities)
    result = []
    for probability in list_of_probabilities:
        result.append(probability / sum_of_probabilities)
    return result

probabilities = [sent_english_prob, sent_french_prob, sent_italian_prob]
normalized_probabilities = get_normalized_probabilities(probabilities)

print('RELATIVE PROBABILITIES')
print('English: ', round(normalized_probabilities[0] * 100, 2), '%', sep='') # I use sep because I don't want a space before the % sign.
print('French: ', round(normalized_probabilities[1] * 100, 2), '%', sep='')
print('Italian: ', round(normalized_probabilities[2] * 100, 2), '%', sep='')
# Out:
# RELATIVE PROBABILITIES
# English: 99.98%
# French: 0.01%
# Italian: 0.01%

# %% [markdown]
# **PS:** For a state-of-the-art Greek dialect classifier using n-grams, take a look at [Greek Dialect Classifier](https://github.com/hb20007/greek-dialect-classifier).
